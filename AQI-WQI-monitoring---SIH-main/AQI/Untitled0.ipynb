# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/bengaluruaqi.csv',header=0,index_col=0)
df
# Out:
#             PM2.5   PM10     NO    NH3     CO    SO2    AQI_Bucket   AQI
# Date
# 01-01-2015    NaN    NaN   3.26  20.36   0.33   3.54           NaN   NaN
# 02-01-2015    NaN    NaN   6.05  23.74   1.35   3.97           NaN   NaN
# 03-01-2015    NaN    NaN  11.91   4.32  17.40  13.61           NaN   NaN
# 04-01-2015    NaN    NaN   7.45   0.87   5.05   6.52           NaN   NaN
# 05-01-2015    NaN    NaN   9.52  31.38   1.83   4.71           NaN   NaN
# ...           ...    ...    ...    ...    ...    ...           ...   ...
# 27-06-2020  16.60  29.48   3.06   6.88   0.67   7.29  Satisfactory  51.0
# 28-06-2020  20.44  26.34   2.69   6.58   0.66   6.60  Satisfactory  61.0
# 29-06-2020  28.68  29.27   3.62   6.80   0.56   6.33  Satisfactory  65.0
# 30-06-2020  14.47  24.26   4.61   6.82   0.56   6.45  Satisfactory  63.0
# 01-07-2020  17.50  30.48   3.95   7.42   0.54   6.66          Good  43.0
#
# [2009 rows x 8 columns]

# %%
df.isna().sum()
# Out:
# PM2.5         146
# PM10          360
# NO              6
# NH3           203
# CO             11
# SO2             6
# AQI_Bucket     99
# AQI            99
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.isna().sum()
# Out:
# PM2.5         0
# PM10          0
# NO            0
# NH3           0
# CO            0
# SO2           0
# AQI_Bucket    0
# AQI           0
# dtype: int64

# %%
df.index
# Out:
# Index(['07-11-2015', '10-11-2015', '13-11-2015', '14-11-2015', '18-11-2015',
#        '19-11-2015', '20-11-2015', '21-11-2015', '22-11-2015', '23-11-2015',
#        ...
#        '22-06-2020', '23-06-2020', '24-06-2020', '25-06-2020', '26-06-2020',
#        '27-06-2020', '28-06-2020', '29-06-2020', '30-06-2020', '01-07-2020'],
#       dtype='object', name='Date', length=1456)

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
df['AQI_Bucket']= encoder.fit_transform(df['AQI_Bucket'])
df['AQI_Bucket'] = df['AQI_Bucket'].astype('float32')
df['AQI_Bucket']
# Out:
# Date
# 07-11-2015    3.0
# 10-11-2015    3.0
# 13-11-2015    3.0
# 14-11-2015    1.0
# 18-11-2015    1.0
#              ...
# 27-06-2020    3.0
# 28-06-2020    3.0
# 29-06-2020    3.0
# 30-06-2020    3.0
# 01-07-2020    0.0
# Name: AQI_Bucket, Length: 1456, dtype: float32

# %%
ds = df.values
ds
# Out:
# array([[ 31.44,  70.46,   3.03, ...,   1.94,   3.  ,  60.  ],
#        [ 12.63,  43.64,   1.46, ...,   2.05,   3.  ,  51.  ],
#        [ 28.22, 153.3 ,   5.8 , ...,   2.69,   3.  ,  61.  ],
#        ...,
#        [ 28.68,  29.27,   3.62, ...,   6.33,   3.  ,  65.  ],
#        [ 14.47,  24.26,   4.61, ...,   6.45,   3.  ,  63.  ],
#        [ 17.5 ,  30.48,   3.95, ...,   6.66,   0.  ,  43.  ]])
